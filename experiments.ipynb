# %%
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Test.jpg")
# img = img[40:1000, 500:1750]
plt.imshow(img);

# %%
img_r = img[:, :, 0]
img_g = img[:, :, 1]
img_b = img[:, :, 2]

# %%
np.mean(img_r), np.mean(img_g), np.mean(img_b)
# Out:
# (95.40945987654321, 95.40945987654321, 95.40945987654321)
